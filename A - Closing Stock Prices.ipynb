# %%
# Dependencies
import requests
import time
from datetime import datetime, timedelta
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
#Load Alpha Vantage API key from .env file
load_dotenv()
av_api_key = os.getenv("AV_API_KEY")
print(av_api_key)

# %%
# create a datetime conversion function
def convert_to_datetime(time_stamp):
    date_format = "%Y%m%dT%H%M%S"
    return datetime.strptime(time_stamp, date_format)

# %%
# Pull in the list of companies

df_SP_500 = pd.read_csv("constituents.csv")
ticker_list = df_SP_500['Symbol'].astype(str).tolist()
ticker_list = [t.replace('.', '-') for t in ticker_list]

for ticker in ticker_list:
    print(ticker)

# %%
# loop through the tickers
counter = 0

for ticker in ticker_list:
    # create a data frame
    df_tickers = pd.DataFrame()

    # Run a counter & time sleep to pause every 75 pulls
    counter = counter + 1
    counter_check = counter % 75
    # print(counter)

    if counter_check == 0:  
        time.sleep(60)

    # Building the Alpha Vantage API query URL to test if it works using IBM
    url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&outputsize=full&symbol=' + ticker + '&apikey=' + "M9BTYXZI7EG8P00S"
    r = requests.get(url)
    data = r.json()

    # Convert JSON to DataFrame
    df_test = pd.DataFrame.from_dict(data['Time Series (Daily)'], orient='index')

    # Reset index to make the date keys a column
    df_test.reset_index(inplace=True)

    # Rename the index column to 'date'
    df_test.rename(columns={'index': 'date'}, inplace=True)

    # convert the date & time to a datetime field
    df_test['date'] = pd.to_datetime(df_test['date'])

    # drop the high, low, adjusted close, dividence and split coefficient columns
    df_test = df_test.drop(['1. open', '2. high', '3. low', '5. adjusted close', '7. dividend amount', '8. split coefficient'], axis=1)
    df_test.rename(columns={'4. close': 'close','6. volume': 'volume'}, inplace=True)

    # Add columns for the close price from one day and one week prior
    df_test['close_1_day_prior'] = df_test['close'].shift(-1)
    df_test['close_1_week_prior'] = df_test['close'].shift(-5)

    # Convert to an integer
    df_test['close'] = df_test['close'].astype(float)
    df_test['close_1_day_prior'] = df_test['close_1_day_prior'].astype(float)
    df_test['close_1_week_prior'] = df_test['close_1_week_prior'].astype(float)


    # Calculate the percent change compared to the prior day and prior week
    df_test['pct_change_1_day'] = df_test['close'].pct_change(periods=-1).astype(float)
    df_test['pct_change_1_week'] = df_test['close'].pct_change(periods=-5).astype(float)

    # filter for rows where the year is 2023
    df_test_2023 = df_test[df_test['date'].dt.year == 2023]
    # Reset index and drop the old index
    df_test_2023.reset_index(drop=True, inplace=True)

    # Create an export location and export the data frame to a CSV
    file_path = '2023_Closing_Stock_Prices/' + ticker + '_stock_data.csv'
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    df_test_2023.to_csv(file_path, index=False)

    print(f"DataFrame exported to {file_path}")
# Out:
# DataFrame exported to 2023_Closing_Stock_Prices/AVGO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/BR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/BRO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/BF-B_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/BLDR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/BG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/BXP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CHRW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CDNS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CZR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CPT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CPB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/COF_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CAH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KMX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CCL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CARR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CTLT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CAT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CBOE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CBRE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CDW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/COR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CNC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CNP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CF_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CRL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SCHW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CHTR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CVX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CMG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CHD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CINF_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CTAS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CSCO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/C_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CFG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CLX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CME_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CMS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CTSH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CMCSA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CAG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/COP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ED_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/STZ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CEG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/COO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CPRT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GLW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CPAY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CTVA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CSGP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/COST_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CTRA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CRWD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CCI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CSX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CMI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CVS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DHR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DRI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DVA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DAY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DECK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DAL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DVN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DXCM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FANG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DLR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DFS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DLTR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/D_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DPZ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DOV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DOW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DHI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DTE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DUK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EMN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ETN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EBAY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ECL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EIX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ELV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EMR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ENPH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ETR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EOG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EPAM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EQT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EFX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EQIX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EQR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ESS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ETSY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EVRG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ES_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EXC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EXPE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EXPD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/EXR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/XOM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FFIV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FDS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FICO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FAST_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FRT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FDX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FIS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FITB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FSLR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FMC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/F_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FTNT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FTV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FOXA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FOX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/BEN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/FCX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GRMN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GEHC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GEV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GEN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GNRC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GIS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GPC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GILD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GPN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GDDY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HAL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HIG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HAS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HCA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DOC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HSIC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HSY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HES_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HPE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HLT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HOLX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HON_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HRL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HST_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HWM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HPQ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HUBB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HUM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HBAN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/HII_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IBM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IEX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IDXX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ITW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/INCY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PODD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/INTC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ICE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IFF_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IPG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/INTU_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ISRG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IVZ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/INVH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IQV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/IRM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/JBHT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/JBL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/JKHY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/J_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/JNJ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/JCI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/JPM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/JNPR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/K_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KVUE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KDP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KEY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KEYS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KMB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KIM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KMI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KKR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KLAC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KHC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/KR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LHX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LRCX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LVS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LDOS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LEN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LLY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LIN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LYV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LKQ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LMT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/L_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LOW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LULU_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LYB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MTB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MRO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MPC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MKTX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MAR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MMC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MLM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MAS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MTCH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MKC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MCD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MCK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MDT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MRK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/META_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MET_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MTD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MGM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MCHP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MU_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MSFT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MAA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MRNA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MHK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MOH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TAP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MDLZ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MPWR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MNST_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MCO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MOS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MSI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/MSCI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NDAQ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NTAP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NFLX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NEM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NWSA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NWS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NEE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NKE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NDSN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NSC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NTRS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NOC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NCLH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NRG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NUE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NVDA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NVR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NXPI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ORLY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/OXY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ODFL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/OMC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ON_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/OKE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ORCL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/OTIS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PCAR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PKG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PANW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PARA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PAYX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PAYC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PYPL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PNR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PEP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PFE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PCG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PSX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PNW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PNC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/POOL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PPG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PPL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PFG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PGR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PLD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PRU_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PEG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PTC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PSA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PHM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/QRVO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/PWR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/QCOM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DGX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RJF_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RTX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/O_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/REG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/REGN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RF_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RSG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RMD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RVTY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ROK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ROL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ROP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ROST_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/RCL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SPGI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/CRM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SBAC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SLB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/STX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SRE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/NOW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SHW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SPG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SWKS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SJM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SNA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SOLV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/LUV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SWK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SBUX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/STT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/STLD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/STE_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SYK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SMCI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SYF_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SNPS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/SYY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TMUS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TROW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TTWO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TPR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TRGP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TGT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TEL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TDY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TFX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TER_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TSLA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TXN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TXT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TMO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TJX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TSCO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TDG_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TRV_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TRMB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TFC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TYL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/TSN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/USB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/UBER_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/UDR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ULTA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/UNP_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/UAL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/UPS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/URI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/UNH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/UHS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VLO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VTR_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VLTO_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VRSN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VRSK_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VZ_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VRTX_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VTRS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VICI_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/V_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VST_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/VMC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WRB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/GWW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WAB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WBA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WMT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/DIS_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WBD_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WAT_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WEC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WFC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WELL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WST_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WDC_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WY_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WMB_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WTW_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/WYNN_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/XEL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/XYL_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/YUM_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ZBRA_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ZBH_stock_data.csv
# DataFrame exported to 2023_Closing_Stock_Prices/ZTS_stock_data.csv
